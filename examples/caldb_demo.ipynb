# %%
from kpicdrp.caldb import det_caldb, trace_caldb
from kpicdrp.data import DetectorFrame

# %%
# View detector calibration database
det_caldb.db
# Out:
#                                              Filepath       Type  \
# 0   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 1   /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 2   /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 3   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 4   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 5   /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 6   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 7   /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 8   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 9   /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 10  /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 11  /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 12  /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 13  /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 14  /Users/taylorvenenciano/Desktop/public_kpic_da...       bkgd
# 15  /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 16  /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
# 17  /Users/taylorvenenciano/Desktop/public_kpic_da...  badpixmap
#
#           Date/Time of Obs.  Integration Time  Coadds  # of Files Used
# 0   2020-07-02T15:25:33.070         29.505600       1                4
# 1   2020-07-02T15:46:33.790        598.963684       1                6
# 2   2020-07-02T15:25:33.070         29.505600       1                4
# 3   2020-07-02T15:40:44.950         59.011200       1                4
# 4   2020-07-02T15:24:39.010          1.475280       1                4
# 5   2020-07-02T15:40:44.950         59.011200       1                4
# 6   2020-07-02T15:46:33.790        598.963684       1                6
# 7   2020-07-02T15:24:39.010          1.475280       1                4
# 8   2020-09-28T15:49:17.270         59.011200       1                3
# 9   2020-09-28T15:37:27.350          1.475280       1                3
# 10  2020-09-28T16:01:07.190        598.963684       1               10
# 11  2020-09-28T15:49:17.270         59.011200       1                3
# 12  2020-09-28T15:37:27.350          1.475280       1                3
# 13  2020-09-28T15:40:02.390          4.425840       1                3
# 14  2020-09-28T15:43:44.750         29.505600       1                3
# 15  2020-09-28T16:01:07.190        598.963684       1               10
# 16  2020-09-28T15:40:02.390          4.425840       1                3
# 17  2020-09-28T15:43:44.750         29.505600       1                3

# %%
# View trace calibration database
trace_caldb.db
# Out:
#                                             Filepath        Date/Time of Obs.  \
# 0  /Users/taylorvenenciano/Desktop/public_kpic_da...  2020-09-28T05:39:09.470
# 1  /Users/taylorvenenciano/Desktop/traces/nspec20...  2020-10-26T10:39:37.850
# 2  /Users/taylorvenenciano/Desktop/traces/nspec21...  2021-04-24T14:57:08.180
# 3  /Users/taylorvenenciano/Desktop/traces/nspec21...  2021-04-25T08:30:55.670
#
#      s1    s2    s3    s4     c0     c1  Echelle Position  \
# 0  True  True  True  True  False  False              63.0
# 1  True  True  True  True  False  False              63.0
# 2  True  True  True  True  False  False              63.0
# 3  True  True  True  True  False  False              63.0
#
#    X-Disperser Position
# 0                 35.76
# 1                 35.76
# 2                 35.76
# 3                 35.76

# %% [markdown]
# Testing to see the get calib function of the databases

# %%
# A random detector frame that I want to get calibration files for
det_frame = DetectorFrame(filepath="/scr3/jruffio/data/kpic/20210424_backgrounds/raw/nspec210424_0288.fits")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1ec0a2c9864d> in <module>
#       1 # A random detector frame that I want to get calibration files for
# ----> 2 det_frame = DetectorFrame(filepath="/scr3/jruffio/data/kpic/20210424_backgrounds/raw/nspec210424_0288.fits")
#
# ~/Documents/GitHub/kpic_pipeline/kpicdrp/data.py in __init__(self, data, header, filepath)
#     177
#     178     def __init__(self, data=None, header=None, filepath=""):
# --> 179         super().__init__(data, header, filepath)
#     180
#     181         if 'ROTATED' not in self.header:
#
# ~/Documents/GitHub/kpic_pipeline/kpicdrp/data.py in __init__(self, data, header, filepath)
#      39         elif len(filepath) > 0:
#      40             # load data/header from disk. assume loaded in primary FITS extention
# ---> 41             with fits.open(filepath) as hdulist:
#      42                 self.data = np.copy(hdulist[0].data)
#      43                 self.header = hdulist[0].header.copy()
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     162         raise ValueError(f'Empty filename: {name!r}')
#     163
# --> 164     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     165                             lazy_load_hdus, **kwargs)
#     166
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     399         """
#     400
# --> 401         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     402                              save_backup=save_backup, cache=cache,
#     403                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1050             if not isinstance(fileobj, _File):
#    1051                 # instantiate a FITS file object (ffo)
# -> 1052                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1053             # The Astropy mode is determined by the _File initializer if the
#    1054             # supplied mode was None
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# ~/opt/miniconda3/envs/database/lib/python3.8/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     390     """
#     391
# --> 392     return open(filename, mode, buffering=0)
#     393
#     394
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scr3/jruffio/data/kpic/20210424_backgrounds/raw/nspec210424_0288.fits'

# %%
# Get best calibration files to use
bkgd = det_caldb.get_calib(det_frame, type="Background")
bpm = det_caldb.get_calib(det_frame, type="BadPixelMap")
trace = trace_caldb.get_calib(det_frame)

# %%
# Checking if det_caldb.get_calib works
print(det_frame.header["TRUITIME"]==bkgd.header["TRUITIME"]==bpm.header["TRUITIME"]) # integration time
print(det_frame.header["COADDS"]==bkgd.header["COADDS"]==bpm.header["COADDS"]) # coadds
print(bkgd.header["DRPNFILE"]>1 and bpm.header["DRPNFILE"]>1) # num of files used
print("Detector Frame time: " + str(det_frame.time_obs))
print("Selected Background time: " + str(bkgd.time_obs))
print("Selected Bad Pixel Map time: " + str(bpm.time_obs))

# %%
# Checking if trace_caldb.get_calib works
print(det_frame.header["DISPPOS"] == trace.header["DISPPOS"]) # x-disperser position
print(det_frame.header["ECHLPOS"] == trace.header["ECHLPOS"]) # echelle position
print("Detector Frame time: " + str(det_frame.time_obs))
print("Selected Trace time: " + str(trace.time_obs))

# %% [markdown]
# Testing the remove entry, create entry, and save functions

# %%
# Remove entry
from kpicdrp.data import BadPixelMap, Background
bkgd1 = Background(filepath="/scr3/kpic/KPIC_Campaign/calibs/20191107/bkgd_bpmap/20191107_background_med_nobars_tint59.0112_coadds1.fits")
badpix1 = BadPixelMap(filepath="/scr3/kpic/KPIC_Campaign/calibs/20191107/bkgd_bpmap/20191107_persistent_badpix_nobars_tint59.0112_coadds1.fits")
det_caldb.remove_entry(bkgd1)
det_caldb.save()
det_caldb.db.tail()

# %%
# Create/update entry
det_caldb.create_entry(badpix1)
det_caldb.create_entry(bkgd1)
det_caldb.save()
det_caldb.db.tail()
